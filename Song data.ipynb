# %%
import pandas as pd
df=pd.read_csv("song_metadata.csv", encoding="latin1")
from pandas import *

# %%
df
# Out:
#                 track_id                                              title  \
# 0     TRACCVZ128F4291A8A                                  Deep Sea Creature
# 1     TRACCMH128F428E4CD                               No Quieras Marcharte
# 2     TRACCSW128F148C7C3                                            If I...
# 3     TRACCXJ128F428F0CF  Werther - Lyric Drama in four Acts/Act I/Alors...
# 4     TRACCVS12903D014F8               Ad Te Clamamus Exsvles Mortva Liberi
# 5     TRACCKS128F42B77AE                                         Murder One
# 6     TRACCQM12903CACC1E                                   On My Feet Again
# 7     TRACCUS128F92E1FEB                                  Bedroom Acoustics
# 8     TRACCJA128F149A144                                            Segredo
# 9     TRACCGB12903CD1B90                          Sajana (Ft Faheem Mazhar)
# 10    TRACCXJ128F92E984B                                            Theresa
# ...

# %%
titles = list(df["title"])

# %%
years = list(df["year"])

# %%
df["love"] = [1 if "love" in str(i).lower() else 0 for i in titles]

# %%
df2=df[df.year != 0]

# %%
df2
# Out:
#                 track_id                                              title  \
# 0     TRACCVZ128F4291A8A                                  Deep Sea Creature
# 1     TRACCMH128F428E4CD                               No Quieras Marcharte
# 4     TRACCVS12903D014F8               Ad Te Clamamus Exsvles Mortva Liberi
# 5     TRACCKS128F42B77AE                                         Murder One
# 8     TRACCJA128F149A144                                            Segredo
# 10    TRACCXJ128F92E984B                                            Theresa
# 16    TRACJJZ12903CCBCDA                                       No Survivors
# 17    TRACJPW128F932CA4C                  Her Golden Robe In Silence Veiled
# 18    TRACJWY12903CB7DBF                                      Same Old Song
# 19    TRACJHJ128F1489FAB                                   The Ride (Album)
# 21    TRACJDX12903CD4917                                    Church Hangover
# ...

# %%
loves = list(df["love"])

# %%
df3 = df2[["title", "year", "love"]].copy()
df3 = df3.groupby(['year', 'love']).count()
df3 = df3.reset_index()
df3
# Out:
#      year  love  title
# 0    1926     0      2
# 1    1927     0      3
# 2    1929     0      1
# 3    1930     0      2
# 4    1934     0      1
# 5    1935     0      2
# 6    1936     0      1
# 7    1940     0      2
# 8    1947     0      2
# 9    1950     1      1
# 10   1953     0      4
# 11   1954     0      1
# 12   1955     0      1
# 13   1956     0      5
# 14   1956     1      2
# 15   1957     0      1
# 16   1958     0      6
# 17   1959     0      8
# 18   1959     1      1
# 19   1960     0      7
# 20   1960     1      2
# 21   1961     0      7
# 22   1962     0      4
# 23   1963     0     15
# 24   1964     0     13
# 25   1965     0      8
# 26   1966     0     11
# 27   1966     1      1
# 28   1967     0     26
# 29   1967     1      3
# ..    ...   ...    ...
# 81   1995     1      5
# 82   1996     0    104
# 83   1996     1      5
# 84   1997     0    128
# 85   1997     1      2
# 86   1998     0    147
# 87   1998     1      4
# 88   1999     0    166
# ...

# %% [markdown]
# df3

# %%
a = [float(i) for i in years]
b = [float(i) for i in love]

# %% [raw]
# a x b

# %%
import numpy as np
import matplotlib.pyplot as plt

x = (0, a)
y = (b)

fig, ax = plt.subplots()

ax.fill(x, y, zorder=10)
ax.grid(True, zorder=5)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-111-b5963020c9fd> in <module>()
#       7 fig, ax = plt.subplots()
#       8
# ----> 9 ax.fill(x, y, zorder=10)
#      10 ax.grid(True, zorder=5)
#      11 plt.show()
#
# /Users/alexamarzina/anaconda/lib/python3.6/site-packages/matplotlib/__init__.py in inner(ax, *args, **kwargs)
#    1890                     warnings.warn(msg % (label_namer, func.__name__),
#    1891                                   RuntimeWarning, stacklevel=2)
# -> 1892             return func(ax, *args, **kwargs)
#    1893         pre_doc = inner.__doc__
#    1894         if pre_doc is None:
#
# /Users/alexamarzina/anaconda/lib/python3.6/site-packages/matplotlib/axes/_axes.py in fill(self, *args, **kwargs)
#    4689
#    4690         patches = []
# -> 4691         for poly in self._get_patches_for_fill(*args, **kwargs):
# ...
