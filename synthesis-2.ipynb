# %%
from bokeh.plotting import figure, output_notebook, show
from bokeh.charts import Bar, output_file, show
from bokeh.models import HoverTool
from bokeh.io import output_file, show
#from bokeh.layouts import widgetbox
#from bokeh.models.widgets import RadioButtonGroup
from bokeh.models.callbacks import CustomJS
from bokeh.models.sources import ColumnDataSource

# %%
output_notebook()
output_file('index.html', title = 'Synthesis 2')
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="c2a412f8-82fa-46b1-8df2-99ab39444c3b">Loading BokehJS ...</span>
#     </div>
# INFO:bokeh.core.state:Session output file 'index.html' already exists, will be overwritten.

# %%
import pandas

# %%
df = pandas.read_excel('pricedata2.xlsx', sheetname='Sheet1')

# %%
hover = HoverTool(
        tooltips=[
            ("Product: ", "@Product"),
            ("Price per unit: ", "@y")
        ]
    )

p = Bar(df, 'Product',values='PricePerUnit', group = 'Store', tools = [hover], bar_width=1, responsive = True )
p.yaxis.axis_label = "Price Per Unit"

'''cds = ColumnDataSource.from_df(df);

callback=CustomJS(args=cds, code="""

//begin js code

var a = 10;
var b = 11;
""")

radio_button_group = RadioButtonGroup(
        labels=["Baking", "Dairy", "Frozen", "Grocery", "Household", "Meat", "Produce", "Snacks"], active=0)

show(widgetbox(radio_button_group))
'''

show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="1b3ac0f5-67c9-4b54-847d-007ed47b2daf"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("1b3ac0f5-67c9-4b54-847d-007ed47b2daf").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("1b3ac0f5-67c9-4b54-847d-007ed47b2daf");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '1b3ac0f5-67c9-4b54-847d-007ed47b2daf' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"28a80853-6288-4bc6-8543-9195c7884a4b":{"roots":{"references":[{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"3886c6df-f0e1-4b14-9b3f-9654b6be4e79","type":"Rect"},{"attributes":{"data_source":{"id":"0e2aa20d-7c84-44be-9c6c-c354a9d00e91","type":"ColumnDataSource"},"glyph":{"id":"ed4596cb-29e4-4ad6-91dd-6b46e2b3507a","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"210490b8-b31e-49f1-82fd-7e018a2dd0f4","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"37f7c74c-d270-4ed9-9f3a-3933abb6df1d","type":"ColumnDataSource"},"glyph":{"id":"1aa0da54-e5c6-4e2c-bb68-0e7b2f763137","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"b34a9e52-6afa-44a8-b5ce-0dcf32ce90c3","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"a883897f-bd6a-4f03-8482-47442398e07e","type":"ColumnDataSource"},"glyph":{"id":"4e3529d6-df55-4065-a361-e5bf9255d7b6","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"be340a5b-ea0a-4ca3-bae9-e9cb1ecd24c2","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"1d0a4e1a-b79c-4a0f-b480-6c31ad0178f0","type":"Rect"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"e600d490-949d-4228-8064-3046e0af9c0b","type":"Rect"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"448509cd-0bd6-4a0a-9edf-7bd85c96892d","type":"Rect"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"8c50c9c2-45d1-4e6c-b320-44f73a10c49f","type":"Rect"},{"attributes":{"label":{"value":"Aldi"},"renderers":[{"id":"9a64acfc-585c-45af-bf86-e73510bc5f4d","type":"GlyphRenderer"}]},"id":"65e0a77e-0967-415e-a0b2-d4f62ed1bb3a","type":"LegendItem"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"40f94996-4874-464b-8e5d-fdb4757da463","type":"Rect"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"28526c2e-46e8-4179-83c0-687266056ec7","type":"Rect"},{"attributes":{"data_source":{"id":"1e8d51bf-2dbc-4b34-b550-b1cf01af190b","type":"ColumnDataSource"},"glyph":{"id":"448509cd-0bd6-4a0a-9edf-7bd85c96892d","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"f2573e0a-bfb9-4021-9098-7baecd866237","type":"GlyphRenderer"},{"attributes":{"callback":null,"factors":["Almond milk","Aluminum foil","Apples (Gala)","Avocado","Bacon","Bananas","Bananas, organic","Batteries, AA","Batteries, AAA","Beef jerky","Blueberries","Boneless skinless chicken breasts","Brown sugar","Brownie mix ","Butter","Canned salmon","Canned tuna","Canned vegetables","Carrots, organic","Cashews","Cat food","Cheese, goat","Chicken thighs","Chicken wings","C ...
